# %%
# !python demo.py --dataset human
# Out:
# Using device: cuda
# Data dimensions:
# QSOCTD input dimension: 103
# Compound dictionary size: 64
# Protein dictionary size: 8393
# /home/hxjia/.conda/envs/torch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#
# Starting training...
# Total epochs: 30
# Batch size: 512
# Learning rate: 0.001
# Weight decay: 0.01
# dataset: human
#
# Epoch 1/30
# ------------------------------------------------------------
#  [===========================>..] | Loss: 0.683                                 10/10
#  [==============================>] | Loss: 0.679                                 11/10
# Classification Loss: 0.6888
# Total Loss: 0.6888
#
# Epoch 1 Results:
# Train Loss: 0.688846
# AUC: 0.795941
# AUPR: 0.680356
# Precision: 0.727634
# Recall: 0.543834
# Time: 203.29s
#
# Epoch 2/30
# ------------------------------------------------------------
# ...
